# %% [markdown]
# # Homework:
#
# Write a program to numerically evaluate the derivative of f(x)=cos x at an arbitrary position x.
#
# 1) Evaluate the derivative at position x using the forward difference scheme. Plot log(Error)=log10|f’(numerically)-f’(analytic)| against log10(dx) for dx=1e-16,1e-15,….,0.1 at x=π/4. You should find Error~$dx^n$; what is n? what is the optimal value for dx.
#
# 2) Repeat the exercise using the central difference scheme. Why this scheme is better?
#
# 3) Repeat (2) for x=0. Why do the results differ? (hint: write out the error term derived in the class explicitly by plugging the derivative of cos or sin)

# %%
import numpy as np

# definitions in Landau - see page 87
# expanding T.S. error 'dx'
# VERY IMPORTANT TO UNDERSTAND 

def derifw(y,x,dx):  #forward difference
    return (y(x+dx)-y(x))/dx

x=1.0 # point we're evaluating
dx=0.1 # incrimentation 
print('x=',x,' and ', 'dx=', dx)
print('forward difference',derifw(np.cos,x,dx))
# Out:
# x= 1.0  and  dx= 0.1
# forward difference -0.8670618444256245

# %%
import numpy as np
import matplotlib.pyplot as plt


# how's the error change with increasing dx ?
# forward difference


# definitions in Landau - see page 87
# expanding T.S. error 'dx'
# VERY IMPORTANT TO UNDERSTAND 

def writeFile(name, n, fwd, cntl):
    f = open(name, "w")
    for i in range(len(n)):
        f.write(str(n[i]))
        f.write("\t")
        f.write(str(fwd[i]))
        f.write("\t")
        f.write(str(cntl[i]))
        f.write("\t")
    f.close()
    return


#forward
def derifw(y,x,dx):  #forward difference
    return (y(x+dx)-y(x))/dx


# central 
def dericd(y,x,dx): # central difference
    return (y(x+dx/2)-y(x-dx/2))/dx

# data 

x= np.pi/4
dxarr=[]
yarr_dericd=[]
yarr_derifw=[]

for dx in 10**np.arange(-16, 0.1,0.1): #input range
    y=dericd(np.cos,x,dx) # actual funct
#    print('dx %g,  y %g'%(dx,y))
    dxarr.append(dx) # adds to dx array
    yarr_dericd.append(y) # adds to dy array
    y=derifw(np.cos,x,dx) # actual funct
    yarr_derifw.append(y)
    
writeFile("HW3 data.txt", dxarr, yarr_dericd, yarr_derifw)  

print(yarr_derifw)
# Out:
# [-1.1102230246251565, -0.8818814953007539, -0.7005033713982581, -1.112859212842373, -0.8839754940337365, -0.702166693715343, -0.8366262454516412, -0.8860744648981417, -0.7038339655368037, -0.6988439892298007, -0.7771561172376159, -0.7055051962406088, -0.7005033713982638, -0.7233584883475485, -0.7513791699286821, -0.7021666937153489, -0.7250760793914283, -0.7088595719185191, -0.7214298146752297, -0.7128208690144026, -0.7105427357601118, -0.7055051962406146, -0.7075084051122522, -0.7122298962191305, -0.7071803952270007, -0.7091883606525081, -0.7083435544824012, -0.7066443857562794, -0.7073531353644993, -0.7072301171005698, -0.7072120666862421, -0.7072689592312219, -0.7075084051122581, -0.7072220297613455, -0.7071803952270065, -0.7070818605713678, -0.7072280528218048, -0.7070874229887343, -0.7071771768731209, -0.7072301171005757, -0.7071010443837853, -0.7070925829321675, -0.7070881030894248, -0.7071107438400671, -0.7071361964523105, -0.7071169689060594, -0.7071165026557503, -0.7071095748503625, -0.7071243893257114, -0.7071183020623046, -0.7071121466140374, -0.7071102205620794, -0.7071091181905725, -0.7071051795440086, -0.7071096771874954, -0.707109947239128, -0.7071081363933016, -0.7071073596642061, -0.7071067934765787, -0.7071071205584828, -0.7071065954989201, -0.707106693036104, -0.7071070166804642, -0.7071068488328336, -0.7071070252610191, -0.7071067874890121, -0.7071070208916468, -0.7071066951083632, -0.7071069694350759, -0.7071068410208928, -0.7071068175435307, -0.7071067812242593, -0.7071068065294586, -0.7071067931898788, -0.7071068042671513, -0.7071067874890179, -0.7071067977913205, -0.7071067837158155, -0.7071067934765903, -0.7071067851133794, -0.707106795339076, -0.7071067900430801, -0.707106792519397, -0.7071067876255885, -0.7071067910075247, -0.7071067945106906, -0.7071067950025721, -0.7071067992221244, -0.7071068040341056, -0.7071068088740808, -0.7071068164333193, -0.707106826200227, -0.7071068373516185, -0.7071068521714287, -0.7071068701233372, -0.7071068928140335, -0.7071069218908917, -0.7071069584940153, -0.7071070042748746, -0.7071070621351484, -0.7071071347342662, -0.7071072263098673, -0.7071073415739509, -0.7071074866124717, -0.7071076692813885, -0.7071078992295614, -0.7071081887103584, -0.7071085531622355, -0.7071090119612671, -0.7071095895603488, -0.7071103167111762, -0.7071112321419208, -0.7071123846028029, -0.7071138354575938, -0.7071156619712372, -0.7071179614116997, -0.7071208562161505, -0.7071245005355241, -0.7071290884274736, -0.7071348641882783, -0.7071421353477965, -0.7071512890540401, -0.707162812662269, -0.7071773196704392, -0.7071955823463765, -0.7072185727995368, -0.707247514646631, -0.7072839480259341, -0.7073298113702564, -0.7073875442534513, -0.707460216696618, -0.7075516916942078, -0.707666829402546, -0.7078117435354341, -0.707994123094129, -0.7082236357329222, -0.7085124329142083, -0.7088757816522959, -0.7093328531417843, -0.7099077049463645, -0.7106305005757078, -0.7115390178819361, -0.7126805050196192, -0.714113948278166, -0.7159128171988672, -0.7181683441723299, -0.7209933696526195, -0.7245267254520416, -0.7289380118802448, -0.7344324061745632, -0.7412547450958895, -0.7496914260840398, -0.7600674512742623, -0.772733828214719, -0.7880369248671384, -0.806255257622265, -0.8274790500504118, -0.8513917138192781, -0.8768884112380235, -0.9014368399891385, -0.9200651963458362]

# %%
import numpy as np
import matplotlib.pyplot as plt

#plt.plot(dxarr,abs(yarr_dericd-np.sin(np.pi/4)),'r-',lw=2,label='central')
plt.plot(dxarr, abs(yarr_derifw-np.sin(np.pi/4)),'b-', lw=2, label='forward')     
plt.xscale('log')
plt.yscale('log')
plt.xlabel('dx')
plt.ylabel('Error')
plt.grid(True)
plt.legend(loc= 'upper right')
plt.show()

print('n=0 and dx=10^15')
# Out:
# n=0 and dx=10^15

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(dxarr,abs(yarr_dericd-np.sin(np.pi/4)),'r-',lw=2,label='central')
plt.plot(dxarr, abs(yarr_derifw-np.sin(np.pi/4)),'b-', lw=2, label='forward')     
plt.xscale('log')
plt.yscale('log')
plt.xlabel('dx')
plt.ylabel('Error')

plt.yticks([0.5,1,2])
plt.grid(True)
plt.legend(loc= 'lower right')
plt.show()

print('CD is better as the error is smaller by a factor of nearly 10')
# Out:
# CD is better as the error is smaller by a factor of nearly 10

# %%
import numpy as np
import matplotlib.pyplot as plt


# how's the error change with increasing dx 
# forward difference


# definitions in Landau - see page 87
# expanding T.S. error 'dx'
# VERY IMPORTANT TO UNDERSTAND 

def writeFile(name, n, cntl):
    f = open(name, "w")
    for i in range(len(n)):
        f.write(str(n[i]))
        f.write("\t")
        f.write(str(cntl[i]))
        f.write("\t")
    f.close()
    return

# central 
def dericd(y,x,dx): # central difference
    return (y(x+dx/2)-y(x-dx/2))/dx

# data 

x= 0.
dxarr=[]
yarr_dericd=[]

for dx in 10**np.arange(-16, 0.1,0.1): #input range
    y=dericd(np.cos,x,dx) # actual funct
#    print('dx %g,  y %g'%(dx,y))
    dxarr.append(dx) # adds to dx array
    yarr_dericd.append(y) # adds to dy array

    
writeFile("HW3 prob 3 data.txt", dxarr, yarr_dericd)  

import numpy as np
import matplotlib.pyplot as plt

plt.plot(dxarr,yarr_dericd,'g-',lw=2,label='x=0')
#plt.plot(dxarr,abs(yarr_dericd-np.sin(0.)),'r-',lw=2,label='central')
plt.xscale('log')
plt.yscale('linear')
plt.xlabel('dx')
plt.ylabel('Error')
plt.grid(True)
plt.legend(loc= 'lower right')
plt.show()

# %% [markdown]
# since we're using central difference theorem, we know from lect 4:
# $dy/dx= y'(x) + dx/24*y^{[3]}$
# but here $ y = cos(x) \rightarrow y' = sin(x)$
# which means for x = 0 the derivative will always be 0
